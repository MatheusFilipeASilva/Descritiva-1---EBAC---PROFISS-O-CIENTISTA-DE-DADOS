# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline


sinasc_raw = pd.read_csv('sinasc_RO_2019.csv')
sinasc_raw.shape
# Out:
# (27028, 69)

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
sns.boxplot(data = sinasc_raw, x='IDADEMAE')
# Out:
# <Axes: xlabel='IDADEMAE'>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sinasc_raw.columns
sns.boxplot(data=sinasc_raw, x='PESO')
# Out:
# <Axes: xlabel='PESO'>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
sns.displot(data=sinasc_raw, x='IDADEMAE', bins=20, alpha = .25, element='step', kde=True)

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
sns.displot(data = sinasc_raw, x = 'PESO', kde = True, element = 'step', alpha = .25)
